# %% [markdown]
# ### Imports

# %%
import subprocess
import sys

from presidio_analyzer import AnalyzerEngine
from services.pii_service.pii_detector import PiiDetector
from services.pii_service.pii_types import PiiTypes

# %% [markdown]
# ### Try presidio-analyzer

# %%
subprocess.check_call([sys.executable, "-m", "spacy", "download", "de_core_news_lg"])

# %%
# Set up the engine, loads the NLP module (spaCy model by default) and other PII recognizers
analyzer = AnalyzerEngine()

# Call analyzer to get results
results = analyzer.analyze(text="My phone number is 212-555-5555",
                           entities=["PHONE_NUMBER"],
                           language='en')

results
# Out:
# [type: PHONE_NUMBER, start: 19, end: 31, score: 0.75]

# %% [markdown]
# ### Try the custom analyzer

# %%
pii_analyzer = PiiDetector()

detection_result = pii_analyzer.analyze_text(
    text="Mein Name ist Max Mustermann und meine Telefonnummer ist 0176-12345678.",
    detection_entities=[p.value for p in PiiTypes]
)

print(detection_result)
# Out:
# Collecting de-core-news-lg==3.8.0
#   Downloading de_core_news_lg-3.8.0-py3-none-any.whl (567.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.8/567.8 MB 1.6 MB/s  0:06:000:00:0100:11
# Installing collected packages: de-core-news-lg
# Successfully installed de-core-news-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# {'detection_results': [DetectionResultItem(information_type='Person', entity_type='PERSON', score=0.85, start_position=14, end_position=28, risk_level=3, hipaa_category='Protected Health Information'), DetectionResultItem(information_type='Home Phone Number, Cell Phone Number', entity_type='PHONE_NUMBER', score=0.4, start_position=57, end_position=70, risk_level=3, hipaa_category='Protected Health Information')], 'detection_count': 2, 'risk_score_mean': 0.625, 'risk_score_median': 0.625, 'detected_pii_types': ['PERSON', 'PHONE_NUMBER'], 'detected_pii_type_frequencies': {'PERSON': 1, 'PHONE_NUMBER': 1}}
