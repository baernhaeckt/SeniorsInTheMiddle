# %% [markdown]
# ### Imports

# %%
import subprocess
import sys

from presidio_analyzer import AnalyzerEngine
from services.pii_service.pii_detector import PiiDetector
from services.pii_service.pii_types import PiiTypes

# %% [markdown]
# ### Try presidio-analyzer

# %%
subprocess.check_call([sys.executable, "-m", "spacy", "download", "de_core_web_lg"])
# Out:
# ✘ No compatible package found for 'de_core_web_lg' (spaCy v3.8.13)
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 subprocess.check_call([sys.executable, "-m", "spacy", "download", "de_core_web_lg"])
#
# File ~/.local/share/uv/python/cpython-3.14.5-macos-aarch64-none/lib/python3.14/subprocess.py:420, in check_call(*popenargs, **kwargs)
#     418     if cmd is None:
#     419         cmd = popenargs[0]
# --> 420     raise CalledProcessError(retcode, cmd)
#     421 return 0
#
# CalledProcessError: Command '['/Users/oliverhofmann/git/baernhackt/SeniorsInTheMiddle/.venv/bin/python', '-m', 'spacy', 'download', 'de_core_web_lg']' returned non-zero exit status 1.

# %%
# Set up the engine, loads the NLP module (spaCy model by default) and other PII recognizers
analyzer = AnalyzerEngine()

# Call analyzer to get results
results = analyzer.analyze(text="My phone number is 212-555-5555",
                           entities=["PHONE_NUMBER"],
                           language='en')

results
# Out:
# [type: PHONE_NUMBER, start: 19, end: 31, score: 0.75]

# %% [markdown]
# ### Try the custom analyzer

# %%
pii_analyzer = PiiDetector()

detection_result = pii_analyzer.analyze_text(
    text="Mein Name ist Hans Gruber und meine Telefonnummer ist +49 171 1234567.",
    detection_entities=[p.value for p in PiiTypes]
)

print(detection_result)
# Out:
# {"detection_results": [{"information_type": "Person", "entity_type": "PERSON", "score": 0.85, "start_position": 14, "end_position": 25, "risk_level": 3, "hipaa_category": "Protected Health Information"}, {"information_type": "Home Phone Number, Cell Phone Number", "entity_type": "PHONE_NUMBER", "score": 0.4, "start_position": 54, "end_position": 69, "risk_level": 3, "hipaa_category": "Protected Health Information"}], "detection_count": 2, "risk_score_mean": 0.625, "risk_score_median": 0.625, "detected_pii_types": ["PERSON", "PHONE_NUMBER"], "detected_pii_type_frequencies": {"PERSON": 1, "PHONE_NUMBER": 1}}
